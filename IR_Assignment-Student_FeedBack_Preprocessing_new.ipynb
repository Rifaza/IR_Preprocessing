# %%
import re, string, unicodedata
import nltk
import contractions
import inflect
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from bs4 import BeautifulSoup
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from textblob import Word
# Out:
# [nltk_data] Downloading package punkt to /home/rifaza/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/rifaza/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/rifaza/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
studentFeed="""Honestly last seven lectures are good. Lectures are understandable. Lecture slides are very useful to self-study also. The given opportunity to ask questions from the lecturer is appreciative. 
"Good :) 
<br />please do recap at class starting it&#039;s better for us.
<br />sometimes teaching speed is very high.
<br />
<br />Thanks ! :)
<br /> "
The lectures are good..but a bit speed.A in class working activity is a must one.So please take another hour in thursdays madame.
"
<br />We can hear your voice clearly and can understand the things you teach. Presentation slides also good source to refer . lf you can do more example questions within the classroom and it will help us to understand the principles well. 
<br />"
Lectures was well structured and well organized. It was easy to understand. Lecture slides and labs were also well organized. 
Lectures were good. understandable. 
The lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of OOP. Motivated to well. Would have been better if we discussed more about the solutions of coding exercisers.   
I think i learned a lot from the codes you write in the board. When i compare my codes with yours i can learn about my mistakes and good coding practices that i should follow. There fore i think it would be great if we can discuss more examples in the class.
madam explained  the oop concepts clearly with examples.lectures were interesting.we want more scenario examples and answers with explanations in future.
I satisfy about first 7 lectures. That way of teaching is really good for coming lectures too.
lectuers are very good. take good effort to make undersatand every student in the room. very helpfull. 
I was able to obtain a clear picture about OOP and its concepts. 
"lecture slides, explanations were very clear.
<br />it&#039;s very good to letting ask questions and explain again with suitable examples.
<br />sometimes, some codes on white board were unclear at the back.
<br />overall very good!!!
<br />"
The lectures were good and clear. And they weren&#039;t too fast. Writing code was somewhat confusing because I didn&#039;t know java before. 
Actually teaching is very good and can understand easily the concepts by examples which are given in the class.it will be more helpful if provide solved questions as well!. thankyou"""

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    return text

# %%
sudent_feedback = denoise_text(studentFeed)
print(sudent_feedback)
# Out:
# Honestly last seven lectures are good. Lectures are understandable. Lecture slides are very useful to self-study also. The given opportunity to ask questions from the lecturer is appreciative.
# "Good :)
# please do recap at class starting it's better for us.
# sometimes teaching speed is very high.
#
# Thanks ! :)
#  "
# The lectures are good..but a bit speed.A in class working activity is a must one.So please take another hour in thursdays madame.
# "
# We can hear your voice clearly and can understand the things you teach. Presentation slides also good source to refer . lf you can do more example questions within the classroom and it will help us to understand the principles well.
# "
# Lectures was well structured and well organized. It was easy to understand. Lecture slides and labs were also well organized.
# Lectures were good. understandable.
# The lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of OOP. Motivated to well. Would have been better if we discussed more about the solutions of coding exercisers.
# I think i learned a lot from the codes you write in the board. When i compare my codes with yours i can learn about my mistakes and good coding practices that i should follow. There fore i think it would be great if we can discuss more examples in the class.
# madam explained  the oop concepts clearly with examples.lectures were interesting.we want more scenario examples and answers with explanations in future.
# I satisfy about first 7 lectures. That way of teaching is really good for coming lectures too.
# lectuers are very good. take good effort to make undersatand every student in the room. very helpfull.
# I was able to obtain a clear picture about OOP and its concepts.
# "lecture slides, explanations were very clear.
# it's very good to letting ask questions and explain again with suitable examples.
# sometimes, some codes on white board were unclear at the back.
# overall very good!!!
# "
# The lectures were good and clear. And they weren't too fast. Writing code was somewhat confusing because I didn't know java before.
# Actually teaching is very good and can understand easily the concepts by examples which are given in the class.it will be more helpful if provide solved questions as well!. thankyou

# %%
def replace_contractions(text):
    """Replace contractions in string of text"""
    return contractions.fix(text)

# %%
student_feedback = replace_contractions(sudent_feedback)
print(student_feedback)
# Out:
# Honestly last seven lectures are good. Lectures are understandable. Lecture slides are very useful to self-study also. The given opportunity to ask questions from the lecturer is appreciative.
# "Good :)
# please do recap at class starting it is better for us.
# sometimes teaching speed is very high.
#
# Thanks ! :)
#  "
# The lectures are good..but a bit speed.A in class working activity is a must one.So please take another hour in thursdays madame.
# "
# We can hear your voice clearly and can understand the things you teach. Presentation slides also good source to refer . lf you can do more example questions within the classroom and it will help us to understand the principles well.
# "
# Lectures was well structured and well organized. It was easy to understand. Lecture slides and labs were also well organized.
# Lectures were good. understandable.
# The lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of OOP. Motivated to well. Would have been better if we discussed more about the solutions of coding exercisers.
# I think i learned a lot from the codes you write in the board. When i compare my codes with yours i can learn about my mistakes and good coding practices that i should follow. There fore i think it would be great if we can discuss more examples in the class.
# madam explained  the oop concepts clearly with examples.lectures were interesting.we want more scenario examples and answers with explanations in future.
# I satisfy about first 7 lectures. That way of teaching is really good for coming lectures too.
# lectuers are very good. take good effort to make undersatand every student in the room. very helpfull.
# I was able to obtain a clear picture about OOP and its concepts.
# "lecture slides, explanations were very clear.
# it is very good to letting ask questions and explain again with suitable examples.
# sometimes, some codes on white board were unclear at the back.
# overall very good!!!
# "
# The lectures were good and clear. And they were not too fast. Writing code was somewhat confusing because I did not know java before.
# Actually teaching is very good and can understand easily the concepts by examples which are given in the class.it will be more helpful if provide solved questions as well!. thankyou

# %%
tokenised_student_feedback = nltk.word_tokenize(student_feedback)
print(tokenised_student_feedback)
# Out:
# ['Honestly', 'last', 'seven', 'lectures', 'are', 'good', '.', 'Lectures', 'are', 'understandable', '.', 'Lecture', 'slides', 'are', 'very', 'useful', 'to', 'self-study', 'also', '.', 'The', 'given', 'opportunity', 'to', 'ask', 'questions', 'from', 'the', 'lecturer', 'is', 'appreciative', '.', '``', 'Good', ':', ')', 'please', 'do', 'recap', 'at', 'class', 'starting', 'it', 'is', 'better', 'for', 'us', '.', 'sometimes', 'teaching', 'speed', 'is', 'very', 'high', '.', 'Thanks', '!', ':', ')', '``', 'The', 'lectures', 'are', 'good..but', 'a', 'bit', 'speed.A', 'in', 'class', 'working', 'activity', 'is', 'a', 'must', 'one.So', 'please', 'take', 'another', 'hour', 'in', 'thursdays', 'madame.', "''", 'We', 'can', 'hear', 'your', 'voice', 'clearly', 'and', 'can', 'understand', 'the', 'things', 'you', 'teach', '.', 'Presentation', 'slides', 'also', 'good', 'source', 'to', 'refer', '.', 'lf', 'you', 'can', 'do', 'more', 'example', 'questions', 'within', 'the', 'classroom', 'and', 'it', 'will', 'help', 'us', 'to', 'understand', 'the', 'principles', 'well.', "''", 'Lectures', 'was', 'well', 'structured', 'and', 'well', 'organized', '.', 'It', 'was', 'easy', 'to', 'understand', '.', 'Lecture', 'slides', 'and', 'labs', 'were', 'also', 'well', 'organized', '.', 'Lectures', 'were', 'good', '.', 'understandable', '.', 'The', 'lecture', 'slides', 'were', 'well', 'organized', 'and', 'the', 'examples', 'done', 'in', 'the', 'class', 'helped', 'a', 'lot', 'to', 'learn', 'this', 'new', 'language', 'and', 'also', 'the', 'principles', 'of', 'OOP', '.', 'Motivated', 'to', 'well', '.', 'Would', 'have', 'been', 'better', 'if', 'we', 'discussed', 'more', 'about', 'the', 'solutions', 'of', 'coding', 'exercisers', '.', 'I', 'think', 'i', 'learned', 'a', 'lot', 'from', 'the', 'codes', 'you', 'write', 'in', 'the', 'board', '.', 'When', 'i', 'compare', 'my', 'codes', 'with', 'yours', 'i', 'can', 'learn', 'about', 'my', 'mistakes', 'and', 'good', 'coding', 'practices', 'that', 'i', 'should', 'follow', '.', 'There', 'fore', 'i', 'think', 'it', 'would', 'be', 'great', 'if', 'we', 'can', 'discuss', 'more', 'examples', 'in', 'the', 'class', '.', 'madam', 'explained', 'the', 'oop', 'concepts', 'clearly', 'with', 'examples.lectures', 'were', 'interesting.we', 'want', 'more', 'scenario', 'examples', 'and', 'answers', 'with', 'explanations', 'in', 'future', '.', 'I', 'satisfy', 'about', 'first', '7', 'lectures', '.', 'That', 'way', 'of', 'teaching', 'is', 'really', 'good', 'for', 'coming', 'lectures', 'too', '.', 'lectuers', 'are', 'very', 'good', '.', 'take', 'good', 'effort', 'to', 'make', 'undersatand', 'every', 'student', 'in', 'the', 'room', '.', 'very', 'helpfull', '.', 'I', 'was', 'able', 'to', 'obtain', 'a', 'clear', 'picture', 'about', 'OOP', 'and', 'its', 'concepts', '.', '``', 'lecture', 'slides', ',', 'explanations', 'were', 'very', 'clear', '.', 'it', 'is', 'very', 'good', 'to', 'letting', 'ask', 'questions', 'and', 'explain', 'again', 'with', 'suitable', 'examples', '.', 'sometimes', ',', 'some', 'codes', 'on', 'white', 'board', 'were', 'unclear', 'at', 'the', 'back', '.', 'overall', 'very', 'good', '!', '!', '!', "''", 'The', 'lectures', 'were', 'good', 'and', 'clear', '.', 'And', 'they', 'were', 'not', 'too', 'fast', '.', 'Writing', 'code', 'was', 'somewhat', 'confusing', 'because', 'I', 'did', 'not', 'know', 'java', 'before', '.', 'Actually', 'teaching', 'is', 'very', 'good', 'and', 'can', 'understand', 'easily', 'the', 'concepts', 'by', 'examples', 'which', 'are', 'given', 'in', 'the', 'class.it', 'will', 'be', 'more', 'helpful', 'if', 'provide', 'solved', 'questions', 'as', 'well', '!', '.', 'thankyou']

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
    return stems

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    words = remove_stopwords(words)
    return words

# %%
words_st_fb = normalize(tokenised_student_feedback)
print(words_st_fb)
# Out:
# ['honestly', 'last', 'seven', 'lectures', 'good', 'lectures', 'understandable', 'lecture', 'slides', 'useful', 'selfstudy', 'also', 'given', 'opportunity', 'ask', 'questions', 'lecturer', 'appreciative', 'good', 'please', 'recap', 'class', 'starting', 'better', 'us', 'sometimes', 'teaching', 'speed', 'high', 'thanks', 'lectures', 'goodbut', 'bit', 'speeda', 'class', 'working', 'activity', 'must', 'oneso', 'please', 'take', 'another', 'hour', 'thursdays', 'madame', 'hear', 'voice', 'clearly', 'understand', 'things', 'teach', 'presentation', 'slides', 'also', 'good', 'source', 'refer', 'lf', 'example', 'questions', 'within', 'classroom', 'help', 'us', 'understand', 'principles', 'well', 'lectures', 'well', 'structured', 'well', 'organized', 'easy', 'understand', 'lecture', 'slides', 'labs', 'also', 'well', 'organized', 'lectures', 'good', 'understandable', 'lecture', 'slides', 'well', 'organized', 'examples', 'done', 'class', 'helped', 'lot', 'learn', 'new', 'language', 'also', 'principles', 'oop', 'motivated', 'well', 'would', 'better', 'discussed', 'solutions', 'coding', 'exercisers', 'think', 'learned', 'lot', 'codes', 'write', 'board', 'compare', 'codes', 'learn', 'mistakes', 'good', 'coding', 'practices', 'follow', 'fore', 'think', 'would', 'great', 'discuss', 'examples', 'class', 'madam', 'explained', 'oop', 'concepts', 'clearly', 'exampleslectures', 'interestingwe', 'want', 'scenario', 'examples', 'answers', 'explanations', 'future', 'satisfy', 'first', 'seven', 'lectures', 'way', 'teaching', 'really', 'good', 'coming', 'lectures', 'lectuers', 'good', 'take', 'good', 'effort', 'make', 'undersatand', 'every', 'student', 'room', 'helpfull', 'able', 'obtain', 'clear', 'picture', 'oop', 'concepts', 'lecture', 'slides', 'explanations', 'clear', 'good', 'letting', 'ask', 'questions', 'explain', 'suitable', 'examples', 'sometimes', 'codes', 'white', 'board', 'unclear', 'back', 'overall', 'good', 'lectures', 'good', 'clear', 'fast', 'writing', 'code', 'somewhat', 'confusing', 'know', 'java', 'actually', 'teaching', 'good', 'understand', 'easily', 'concepts', 'examples', 'given', 'classit', 'helpful', 'provide', 'solved', 'questions', 'well', 'thankyou']

# %%
def stem_and_lemmatize(words):
    stems = stem_words(words)
    lemmas = lemmatize_verbs(words)
    return stems, lemmas

stems, lemmas = stem_and_lemmatize(words_st_fb)
print('Student Feed back - Stemmed:\n', stems)
print('\nStudent Feed back  - Lemmatized:\n', lemmas)
# Out:
# Student Feed back - Stemmed:
#  ['honest', 'last', 'sev', 'lect', 'good', 'lect', 'understand', 'lect', 'slid', 'us', 'selfstudy', 'also', 'giv', 'opportun', 'ask', 'quest', 'lect', 'apprecy', 'good', 'pleas', 'recap', 'class', 'start', 'bet', 'us', 'sometim', 'teach', 'spee', 'high', 'thank', 'lect', 'goodbut', 'bit', 'speed', 'class', 'work', 'act', 'must', 'oneso', 'pleas', 'tak', 'anoth', 'hour', 'thursday', 'madam', 'hear', 'voic', 'clear', 'understand', 'thing', 'teach', 'pres', 'slid', 'also', 'good', 'sourc', 'ref', 'lf', 'exampl', 'quest', 'within', 'classroom', 'help', 'us', 'understand', 'principl', 'wel', 'lect', 'wel', 'structured', 'wel', 'org', 'easy', 'understand', 'lect', 'slid', 'lab', 'also', 'wel', 'org', 'lect', 'good', 'understand', 'lect', 'slid', 'wel', 'org', 'exampl', 'don', 'class', 'help', 'lot', 'learn', 'new', 'langu', 'also', 'principl', 'oop', 'mot', 'wel', 'would', 'bet', 'discuss', 'solv', 'cod', 'exerc', 'think', 'learn', 'lot', 'cod', 'writ', 'board', 'comp', 'cod', 'learn', 'mistak', 'good', 'cod', 'pract', 'follow', 'for', 'think', 'would', 'gre', 'discuss', 'exampl', 'class', 'madam', 'explain', 'oop', 'conceiv', 'clear', 'exampleslect', 'interestingw', 'want', 'scenario', 'exampl', 'answ', 'expl', 'fut', 'satisfy', 'first', 'sev', 'lect', 'way', 'teach', 'real', 'good', 'com', 'lect', 'lectu', 'good', 'tak', 'good', 'effort', 'mak', 'undersatand', 'every', 'stud', 'room', 'helpful', 'abl', 'obtain', 'clear', 'pict', 'oop', 'conceiv', 'lect', 'slid', 'expl', 'clear', 'good', 'let', 'ask', 'quest', 'explain', 'suit', 'exampl', 'sometim', 'cod', 'whit', 'board', 'unclear', 'back', 'overal', 'good', 'lect', 'good', 'clear', 'fast', 'writ', 'cod', 'somewh', 'confus', 'know', 'jav', 'act', 'teach', 'good', 'understand', 'easy', 'conceiv', 'exampl', 'giv', 'classit', 'help', 'provid', 'solv', 'quest', 'wel', 'thankyou']
#
# Student Feed back  - Lemmatized:
#  ['honestly', 'last', 'seven', 'lecture', 'good', 'lecture', 'understandable', 'lecture', 'slide', 'useful', 'selfstudy', 'also', 'give', 'opportunity', 'ask', 'question', 'lecturer', 'appreciative', 'good', 'please', 'recap', 'class', 'start', 'better', 'us', 'sometimes', 'teach', 'speed', 'high', 'thank', 'lecture', 'goodbut', 'bite', 'speeda', 'class', 'work', 'activity', 'must', 'oneso', 'please', 'take', 'another', 'hour', 'thursdays', 'madame', 'hear', 'voice', 'clearly', 'understand', 'things', 'teach', 'presentation', 'slide', 'also', 'good', 'source', 'refer', 'lf', 'example', 'question', 'within', 'classroom', 'help', 'us', 'understand', 'principles', 'well', 'lecture', 'well', 'structure', 'well', 'organize', 'easy', 'understand', 'lecture', 'slide', 'labs', 'also', 'well', 'organize', 'lecture', 'good', 'understandable', 'lecture', 'slide', 'well', 'organize', 'examples', 'do', 'class', 'help', 'lot', 'learn', 'new', 'language', 'also', 'principles', 'oop', 'motivate', 'well', 'would', 'better', 'discuss', 'solutions', 'cod', 'exercisers', 'think', 'learn', 'lot', 'cod', 'write', 'board', 'compare', 'cod', 'learn', 'mistake', 'good', 'cod', 'practice', 'follow', 'fore', 'think', 'would', 'great', 'discuss', 'examples', 'class', 'madam', 'explain', 'oop', 'concepts', 'clearly', 'exampleslectures', 'interestingwe', 'want', 'scenario', 'examples', 'answer', 'explanations', 'future', 'satisfy', 'first', 'seven', 'lecture', 'way', 'teach', 'really', 'good', 'come', 'lecture', 'lectuers', 'good', 'take', 'good', 'effort', 'make', 'undersatand', 'every', 'student', 'room', 'helpfull', 'able', 'obtain', 'clear', 'picture', 'oop', 'concepts', 'lecture', 'slide', 'explanations', 'clear', 'good', 'let', 'ask', 'question', 'explain', 'suitable', 'examples', 'sometimes', 'cod', 'white', 'board', 'unclear', 'back', 'overall', 'good', 'lecture', 'good', 'clear', 'fast', 'write', 'code', 'somewhat', 'confuse', 'know', 'java', 'actually', 'teach', 'good', 'understand', 'easily', 'concepts', 'examples', 'give', 'classit', 'helpful', 'provide', 'solve', 'question', 'well', 'thankyou']

# %%
from textblob import TextBlob


def correct_sentence_spelling(sentence):
    
    sentence = TextBlob(sentence)
    
    result = sentence.correct()
    
    print(result)

# %%
def correct_word_spelling(word):
    
    word = Word(word)
    
    result = word.correct()
    
    print(result)

# %%
correct_word_spelling(words_st_fb[0])
# Out:
# honestly

# %%
for x in words_st_fb:
    correct_word_spelling(x)
# Out:
# honestly
# last
# seven
# lectures
# good
# lectures
# understandable
# lecture
# sides
# useful
# selfstudy
# also
# given
# opportunity
# ask
# questions
# lecturer
# appreciative
# good
# please
# reap
# class
# starting
# better
# us
# sometimes
# teaching
# speed
# high
# thanks
# lectures
# goodby
# bit
# speed
# class
# working
# activity
# must
# ones
# please
# take
# another
# hour
# thursdays
# madame
# hear
# voice
# clearly
# understand
# things
# teach
# presentation
# sides
# also
# good
# source
# refer
# of
# example
# questions
# within
# classroom
# help
# us
# understand
# principles
# well
# lectures
# well
# structures
# well
# organized
# easy
# understand
# lecture
# sides
# laws
# also
# well
# organized
# lectures
# good
# understandable
# lecture
# sides
# well
# organized
# examples
# done
# class
# helped
# lot
# learn
# new
# language
# also
# principles
# top
# motivate
# well
# would
# better
# discussed
# solutions
# coming
# exercises
# think
# learned
# lot
# codes
# write
# board
# compare
# codes
# learn
# mistakes
# good
# coming
# practices
# follow
# fore
# think
# would
# great
# discuss
# examples
# class
# madam
# explained
# top
# concepts
# clearly
# exampleslectures
# interesting
# want
# scenario
# examples
# answers
# explanations
# future
# satisfy
# first
# seven
# lectures
# way
# teaching
# really
# good
# coming
# lectures
# lectures
# good
# take
# good
# effort
# make
# understand
# every
# student
# room
# helpful
# able
# obtain
# clear
# picture
# top
# concepts
# lecture
# sides
# explanations
# clear
# good
# letting
# ask
# questions
# explain
# suitable
# examples
# sometimes
# codes
# white
# board
# unclear
# back
# overall
# good
# lectures
# good
# clear
# fast
# writing
# code
# somewhat
# confusing
# know
# cava
# actually
# teaching
# good
# understand
# easily
# concepts
# examples
# given
# classic
# helpful
# provide
# solved
# questions
# well
# thankyou
